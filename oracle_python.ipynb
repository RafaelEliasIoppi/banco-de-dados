# %%
# !pip install oracledb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 27.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import sys
sys.path.insert(0,'/content/gdrive/MyDrive/python/wallet')

# %%
# Conexão
import oracledb

def conexao():

  con = oracledb.connect(
          user="usr10",
          password="Bancodedados@10",
          dsn="oracleaula_high",
          config_dir="/content/gdrive/MyDrive/python/wallet",
          wallet_location="/content/gdrive/MyDrive/python/wallet",
          wallet_password="banco2#2026"
      )

  cursor = con.cursor()
  cursor.execute("SELECT 'Conexão OK' FROM dual")

  resultado = cursor.fetchone()
  print(resultado[0])

  cursor.close()

  return con

# %%
def insere(nome, sal_min,sal_max):

    try:

      cursor = con.cursor()
                # call the stored procedure
      cursor.callproc('insert_cargo', [nome, sal_min, sal_max])
      con.commit()

      print("ok")

    except con.Error as error:
        print(error)
    cursor.close()

# %%
def consulta(con):
  cursor = con.cursor()
  cursor.execute("SELECT * FROM cargo")

  for row in cursor:
    print(row)

# Fechar
  cursor.close()

# %%
if __name__ == '__main__':
  con = conexao()
  consulta(con)
  cargo = input("Cargo: \n")
  salario1 = float(input("Salário mínimo: \n"))
  salario2 = float(input("Salário máximo: \n"))
  insere(cargo, salario1,salario2)
  consulta(con)
# Out:
# Conexão OK
# (1, 'Vendedor', 1000, 5000)
# (2, 's', 2, 3)
# Cargo:
# s
# Salário mínimo:
# 300
# Salário máximo:
# 400
# ok
# (1, 'Vendedor', 1000, 5000)
# (2, 's', 2, 3)
# (3, 's', 300, 400)

# %%
con.close()
